# %%
import pandas as pd
import pickle

# %%
df=pd.read_csv(r"C:\Users\hcsta\Desktop\Data_bank\synthetic_health_data.csv")

# %%
df.head()
# Out:
#    age     diet  exercise_days  sleep_hours  stress   bmi smoking alcohol  \
# 0   56     Poor              3            4    High  19.9      No    High
# 1   69  Average              2            5    High  33.9      No     Low
# 2   46  Average              7           12  Medium  31.0     Yes     Low
# 3   32     Good              1           11    High  38.1      No    High
# 4   60     Good              6           11     Low  34.6      No     Low
#
#   family_history risk_level
# 0            Yes       High
# 1            Yes       High
# 2            Yes     Medium
# 3             No     Medium
# 4            Yes     Medium

# %%
df.shape
# Out:
# (4000, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4000 non-null   int64
#  1   diet            4000 non-null   object
#  2   exercise_days   4000 non-null   int64
#  3   sleep_hours     4000 non-null   int64
#  4   stress          4000 non-null   object
#  5   bmi             4000 non-null   float64
#  6   smoking         4000 non-null   object
#  7   alcohol         4000 non-null   object
#  8   family_history  4000 non-null   object
#  9   risk_level      4000 non-null   object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 312.6+ KB

# %%
df.isna().sum()
# Out:
# age               0
# diet              0
# exercise_days     0
# sleep_hours       0
# stress            0
# bmi               0
# smoking           0
# alcohol           0
# family_history    0
# risk_level        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['age'].max()
# Out:
# 80

# %%
df['diet'].value_counts()
# Out:
# diet
# Average    1987
# Poor       1216
# Good        797
# Name: count, dtype: int64

# %%
df['exercise_days'].max()
# Out:
# 7

# %%
df['sleep_hours'].max()
# Out:
# 12

# %%
df['bmi'].min()
# Out:
# 15.0

# %%
df.head()
# Out:
#    age     diet  exercise_days  sleep_hours  stress   bmi smoking alcohol  \
# 0   56     Poor              3            4    High  19.9      No    High
# 1   69  Average              2            5    High  33.9      No     Low
# 2   46  Average              7           12  Medium  31.0     Yes     Low
# 3   32     Good              1           11    High  38.1      No    High
# 4   60     Good              6           11     Low  34.6      No     Low
#
#   family_history risk_level
# 0            Yes       High
# 1            Yes       High
# 2            Yes     Medium
# 3             No     Medium
# 4            Yes     Medium

# %%
from sklearn.preprocessing import LabelEncoder

# %%
categorical_col=['diet','stress','smoking','alcohol','family_history','risk_level']

# %%
encoders={}

# %%
for i in categorical_col:
    le=LabelEncoder()
    df[i]=le.fit_transform(df[i])
    encoders[i]=le

# %%
# print(encoders['diet'].classes_)

# %%
df.head()
# Out:
#    age  diet  exercise_days  sleep_hours  stress   bmi  smoking  alcohol  \
# 0   56     2              3            4       0  19.9        0        0
# 1   69     0              2            5       0  33.9        0        1
# 2   46     0              7           12       2  31.0        1        1
# 3   32     1              1           11       0  38.1        0        0
# 4   60     1              6           11       1  34.6        0        1
#
#    family_history  risk_level
# 0               1           0
# 1               1           0
# 2               1           2
# 3               0           2
# 4               1           2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4000 non-null   int64
#  1   diet            4000 non-null   int32
#  2   exercise_days   4000 non-null   int64
#  3   sleep_hours     4000 non-null   int64
#  4   stress          4000 non-null   int32
#  5   bmi             4000 non-null   float64
#  6   smoking         4000 non-null   int32
#  7   alcohol         4000 non-null   int32
#  8   family_history  4000 non-null   int32
#  9   risk_level      4000 non-null   int32
# dtypes: float64(1), int32(6), int64(3)
# memory usage: 218.9 KB

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop(columns='risk_level',axis=1)
y=df['risk_level']

# %%
print(x.columns)
# Out:
# Index(['age', 'diet', 'exercise_days', 'sleep_hours', 'stress', 'bmi',
#        'smoking', 'alcohol', 'family_history'],
#       dtype='object')

# %%
print(y.name)
# Out:
# risk_level

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (4000, 9) (3200, 9) (800, 9)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
# model=LogisticRegression()
model=RandomForestClassifier(n_estimators=100,random_state=42)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
acc=accuracy_score(y_pred,y_test)

# %%
print(acc)
# Out:
# 0.96375

# %%
# demo

# %%
model.predict([[19,0,7,12,2,31.0,1,1,1]])
# Out:
# c:\Users\hcsta\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([2])

# %%
df.head()
# Out:
#    age  diet  exercise_days  sleep_hours  stress   bmi  smoking  alcohol  \
# 0   56     2              3            4       0  19.9        0        0
# 1   69     0              2            5       0  33.9        0        1
# 2   46     0              7           12       2  31.0        1        1
# 3   32     1              1           11       0  38.1        0        0
# 4   60     1              6           11       1  34.6        0        1
#
#    family_history  risk_level
# 0               1           0
# 1               1           0
# 2               1           2
# 3               0           2
# 4               1           2

# %%
pickle.dump(model,open("risk_predictor.pkl","wb"))

# %%
with open("label_encoders.pkl", "wb") as f:
    pickle.dump(encoders, f)
